# %%
import numpy as np
import random

# %%
s = np.arange(1,10001)

# %%
x = np.random.choice(s,10000,True)

# %%
len(np.unique(x))
# Out:
# 6306

# %%
import scipy
import matplotlib.pyplot as plt
X1 = scipy.io.loadmat('ex2.mat')['X1']
X2 = scipy.io.loadmat('ex2.mat')['X2']

# %%
plt.scatter(X1,X2)

# %%
X2_shuf = X2[np.random.permutation(1000)]

# %%
plt.scatter(X1,X2_shuf)

# %%
from vecarrow import *

# %%
A1 = np.array([[1,0],[0,1]])
A2 = np.array([[-2,0],[0,-2]])
A3 = np.array([[1,-1],[1,1]])*(1/np.sqrt(2))
x = np.array([1,2])

# %%
vecarrow(x)
A1x = A1@x
vecarrow(A1x)
A2x = A2@x
vecarrow(A2x)
A3x = A3@x
vecarrow(A3x)
plt.xlim(-2,2)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)
